# %%
import os
os.chdir('E:\学习\python\py_codbase\PK_LLM')
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY
from PK_LLM_endfront.D_retriever import (
    chains,
    prompts,
    retrivers
)

# %%
rc = chains.RagChain(step_back=True)
rc.answer_func("如何解决全氟化物在人体内的暴露问题")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\donkey\.conda\envs\EDT\Lib\site-packages\httpcore\_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File c:\Users\donkey\.conda\envs\EDT\Lib\site-packages\httpcore\_backends\sync.py:100, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#      99 with map_exceptions(exc_map):
# --> 100     sock = socket.create_connection(
#     101         address,
#     102         timeout,
#     103         source_address=source_address,
#     104     )
#     105     for option in socket_options:
#
# File c:\Users\donkey\.conda\envs\EDT\Lib\socket.py:851, in create_connection(address, timeout, source_address, all_errors)
#     850 if not all_errors:
# --> 851     raise exceptions[0]
# ...

# %%
rc.answer_func("如何解决全氟化物在人体内的暴露问题")
# Out:
# 'Based on the provided document content, the issue of exposure to organic fluorinated compounds in the human body can be addressed through analytical techniques aimed at identifying and managing potential health hazards. \n\nFirstly, it is crucial to understand the risks associated with organic fluorinated compounds and their presence in environmental media and biota. Analytical methods play a vital role in detecting these compounds and assessing their adverse effects, bioaccumulation, mobility, and persistence. Techniques such as gas chromatography, mass spectrometry, and thermal desorption can be utilized for targeted chemical analysis to identify public health or environmental hazards.\n\nMoreover, the study on the photocatalytic elimination of microorganisms and chemical contaminants highlights the effectiveness of analytical techniques in reducing bacteria concentration in indoor air. This demonstrates the importance of utilizing advanced methods like photocatalysis combined wit
# ...

# %%
# inin retriever chain whitch is subchain of rag
subchain = chains.SubChain(r1=True,r2=True,rag_fusion=True,kb_id=1,vb_path='retrievers')
subchain.chain.invoke("如何解决全氟化物在人体内的暴露问题")
# Out:
# c:\Users\donkey\.conda\envs\EDT\Lib\site-packages\langchain_core\_api\beta_decorator.py:87: LangChainBetaWarning: The function `loads` is in beta. It is actively being worked on, so the API may change.
#   warn_beta(
# {'question': '如何解决全氟化物在人体内的暴露问题',
# ...

# %%
## demo for Ablation 
subchain = chains.SubChain_1(r1=True,r2=True,rag_fusion=False,kb_id=1,vb_path='retrievers')
subchain.chain.invoke("如何解决全氟化物在人体内的暴露问题")
# Out:
# {'question': '如何解决全氟化物在人体内的暴露问题',
# ...

# %%
## demo for Ablation 
subchain = chains.SubChain_1(r1=False,r2=True,rag_fusion=False,kb_id=1,vb_path='retrievers')
subchain.chain.invoke("如何解决全氟化物在人体内的暴露问题")
# Out:
# {'question': '如何解决全氟化物在人体内的暴露问题',
# ...
